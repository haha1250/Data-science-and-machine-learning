# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# # Prepare Data

# %%
store_data = pd.read_excel('./du lieu cung cap/ItemList.xlsx',header=None)
store_data.head()
# Out:
#             0                   1                    2       3    4    5   \
# 0      sausage          whole milk  semi-finished bread  yogurt  NaN  NaN
# 1   whole milk              pastry          salty snack     NaN  NaN  NaN
# 2  canned beer     misc. beverages                  NaN     NaN  NaN  NaN
# 3      sausage    hygiene articles                  NaN     NaN  NaN  NaN
# 4         soda  pickled vegetables                  NaN     NaN  NaN  NaN
#
#     6    7    8    9    10
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14963 entries, 0 to 14962
# Data columns (total 11 columns):
# 0     14963 non-null object
# 1     14963 non-null object
# 2     4883 non-null object
# 3     2185 non-null object
# 4     795 non-null object
# 5     451 non-null object
# 6     276 non-null object
# 7     196 non-null object
# 8     51 non-null object
# 9     1 non-null object
# 10    1 non-null object
# dtypes: object(11)
# memory usage: 1.3+ MB

# %%
store_data.tail()
# Out:
#                           0                 1                    2       3   \
# 14958         tropical fruit           berries     other vegetables  yogurt
# 14959          bottled water             herbs                  NaN     NaN
# 14960  fruit/vegetable juice            onions                  NaN     NaN
# 14961                   soda   root vegetables  semi-finished bread     NaN
# 14962           bottled beer  other vegetables                  NaN     NaN
#
#                    4        5    6    7    8    9    10
# 14958  kitchen towels  napkins  NaN  NaN  NaN  NaN  NaN
# 14959             NaN      NaN  NaN  NaN  NaN  NaN  NaN
# 14960             NaN      NaN  NaN  NaN  NaN  NaN  NaN
# 14961             NaN      NaN  NaN  NaN  NaN  NaN  NaN
# 14962             NaN      NaN  NaN  NaN  NaN  NaN  NaN

# %%
records = []
for i in range(0, store_data.shape[0]):
    records.append([str(store_data.values[i,j]) for j in range(0, store_data.shape[1])])

# %%
records[0]
# Out:
# ['sausage',
#  'whole milk',
#  'semi-finished bread',
#  'yogurt',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
len(records)
# Out:
# 14963

# %%
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df.shape
# Out:
# (14963, 168)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14963 entries, 0 to 14962
# Columns: 168 entries, Instant food products to zwieback
# dtypes: bool(168)
# memory usage: 2.4 MB

# %%
df.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# 1           False  False          False             False  False    False
# 2           False  False          False             False  False    False
# 3           False  False          False             False  False    False
# 4           False  False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False        True    True     False
# 1       False        True   False     False
# 2       False       False   False     False
# 3       False       False   False     False
# 4       False       False   False     False
#
# [5 rows x 168 columns]

# %%
df.columns
# Out:
# Index(['Instant food products', 'UHT-milk', 'abrasive cleaner',
#        'artif. sweetener', 'baby cosmetics', 'bags', 'baking powder',
#        'bathroom cleaner', 'beef', 'berries',
#        ...
#        'turkey', 'vinegar', 'waffles', 'whipped/sour cream', 'whisky',
#        'white bread', 'white wine', 'whole milk', 'yogurt', 'zwieback'],
#       dtype='object', length=168)

# %%
df = df.drop(['nan'], axis=1)

# %%
df.isnull().any()
# Out:
# Instant food products    False
# UHT-milk                 False
# abrasive cleaner         False
# artif. sweetener         False
# baby cosmetics           False
#                          ...
# white bread              False
# white wine               False
# whole milk               False
# yogurt                   False
# zwieback                 False
# Length: 167, dtype: bool

# %% [markdown]
# # 1.Apply Apriori

# %%
frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True)
frequent_itemsets.head()
# Out:
#     support                 itemsets
# 0  0.004010  (Instant food products)
# 1  0.021386               (UHT-milk)
# 2  0.001470       (abrasive cleaner)
# 3  0.001938       (artif. sweetener)
# 4  0.008087          (baking powder)

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric='confidence', min_threshold=0.003)
# Out:
#                 antecedents            consequents  antecedent support  \
# 0                (UHT-milk)        (bottled water)            0.021386
# 1           (bottled water)             (UHT-milk)            0.060683
# 2                (UHT-milk)     (other vegetables)            0.021386
# 3        (other vegetables)             (UHT-milk)            0.122101
# 4                (UHT-milk)           (rolls/buns)            0.021386
# ...                     ...                    ...                 ...
# 1233      (yogurt, sausage)           (whole milk)            0.005748
# 1234  (whole milk, sausage)               (yogurt)            0.008955
# 1235               (yogurt)  (whole milk, sausage)            0.085879
# 1236           (whole milk)      (yogurt, sausage)            0.157923
# 1237              (sausage)   (whole milk, yogurt)            0.060349
#
#       consequent support   support  confidence      lift  leverage  conviction
# 0               0.060683  0.001069    0.050000  0.823954 -0.000228    0.988755
# 1               0.021386  0.001069    0.017621  0.823954 -0.000228    0.996168
# 2               0.122101  0.002139    0.100000  0.818993 -0.000473    0.975443
# 3               0.021386  0.002139    0.017515  0.818993 -0.000473    0.996060
# 4               0.110005  0.001804    0.084375  0.767013 -0.000548    0.972009
# ...                  ...       ...         ...       ...       ...         ...
# 1233            0.157923  0.001470    0.255814  1.619866  0.000563    1.131541
# 1234            0.085879  0.001470    0.164179  1.911760  0.000701    1.093681
# 1235            0.008955  0.001470    0.017121  1.911760  0.000701    1.008307
# 1236            0.005748  0.001470    0.009310  1.619866  0.000563    1.003596
# 1237            0.011161  0.001470    0.024363  2.182917  0.000797    1.013532
#
# [1238 rows x 9 columns]

# %%
rules = association_rules(frequent_itemsets, metric='lift', min_threshold=1.4)
rules
# Out:
#               antecedents            consequents  antecedent support  \
# 0             (beverages)              (sausage)            0.016574
# 1               (sausage)            (beverages)            0.060349
# 2   (specialty chocolate)         (citrus fruit)            0.015973
# 3          (citrus fruit)  (specialty chocolate)            0.053131
# 4                  (curd)              (sausage)            0.033683
# 5               (sausage)                 (curd)            0.060349
# 6             (detergent)               (yogurt)            0.008621
# 7                (yogurt)            (detergent)            0.085879
# 8        (tropical fruit)                (flour)            0.067767
# 9                 (flour)       (tropical fruit)            0.009757
# 10            (pip fruit)          (hard cheese)            0.049054
# 11          (hard cheese)            (pip fruit)            0.014703
# 12               (pastry)              (napkins)            0.051728
# 13              (napkins)               (pastry)            0.022121
# 14     (processed cheese)      (root vegetables)            0.010158
# 15      (root vegetables)     (processed cheese)            0.069572
# 16          (soft cheese)               (yogurt)            0.010025
# 17               (yogurt)          (soft cheese)            0.085879
# 18     (soda, whole milk)              (sausage)            0.011629
# 19              (sausage)     (soda, whole milk)            0.060349
# 20   (whole milk, yogurt)              (sausage)            0.011161
# 21      (yogurt, sausage)           (whole milk)            0.005748
# 22  (whole milk, sausage)               (yogurt)            0.008955
# 23               (yogurt)  (whole milk, sausage)            0.085879
# 24           (whole milk)      (yogurt, sausage)            0.157923
# 25              (sausage)   (whole milk, yogurt)            0.060349
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.060349  0.001537    0.092742  1.536764  0.000537    1.035704
# 1             0.016574  0.001537    0.025471  1.536764  0.000537    1.009129
# 2             0.053131  0.001403    0.087866  1.653762  0.000555    1.038081
# 3             0.015973  0.001403    0.026415  1.653762  0.000555    1.010726
# 4             0.060349  0.002941    0.087302  1.446615  0.000908    1.029531
# 5             0.033683  0.002941    0.048726  1.446615  0.000908    1.015814
# 6             0.085879  0.001069    0.124031  1.444261  0.000329    1.043555
# 7             0.008621  0.001069    0.012451  1.444261  0.000329    1.003878
# 8             0.009757  0.001069    0.015779  1.617141  0.000408    1.006118
# 9             0.067767  0.001069    0.109589  1.617141  0.000408    1.046969
# 10            0.014703  0.001069    0.021798  1.482586  0.000348    1.007254
# 11            0.049054  0.001069    0.072727  1.482586  0.000348    1.025530
# 12            0.022121  0.001738    0.033592  1.518529  0.000593    1.011869
# 13            0.051728  0.001738    0.078550  1.518529  0.000593    1.029109
# 14            0.069572  0.001069    0.105263  1.513019  0.000363    1.039891
# 15            0.010158  0.001069    0.015370  1.513019  0.000363    1.005293
# 16            0.085879  0.001270    0.126667  1.474952  0.000409    1.046704
# 17            0.010025  0.001270    0.014786  1.474952  0.000409    1.004833
# 18            0.060349  0.001069    0.091954  1.523708  0.000368    1.034806
# 19            0.011629  0.001069    0.017719  1.523708  0.000368    1.006200
# 20            0.060349  0.001470    0.131737  2.182917  0.000797    1.082219
# 21            0.157923  0.001470    0.255814  1.619866  0.000563    1.131541
# 22            0.085879  0.001470    0.164179  1.911760  0.000701    1.093681
# 23            0.008955  0.001470    0.017121  1.911760  0.000701    1.008307
# 24            0.005748  0.001470    0.009310  1.619866  0.000563    1.003596
# 25            0.011161  0.001470    0.024363  2.182917  0.000797    1.013532

# %% [markdown]
# # 2.Information search

# %%
for row in rules.iterrows():
    if 'sausage' in row[1][0]:
        print(row)
# Out:
# (1, antecedents             (sausage)
# consequents           (beverages)
# antecedent support      0.0603489
# consequent support      0.0165742
# support                0.00153712
# confidence              0.0254707
# lift                      1.53676
# leverage               0.00053689
# conviction                1.00913
# Name: 1, dtype: object)
# (5, antecedents             (sausage)
# consequents                (curd)
# antecedent support      0.0603489
# consequent support      0.0336831
# support                0.00294059
# confidence              0.0487265
# lift                      1.44662
# leverage              0.000907851
# conviction                1.01581
# Name: 5, dtype: object)
# (19, antecedents                    (sausage)
# consequents           (soda, whole milk)
# antecedent support             0.0603489
# consequent support             0.0116287
# support                        0.0010693
# confidence                     0.0177187
# lift                             1.52371
# leverage                     0.000367526
# conviction                        1.0062
# Name: 19, dtype: object)
# (21, antecedents           (yogurt, sausage)
# consequents                (whole milk)
# antecedent support           0.00574751
# consequent support             0.157923
# support                      0.00147029
# confidence                     0.255814
# lift                            1.61987
# leverage                     0.00056263
# conviction                      1.13154
# Name: 21, dtype: object)
# (22, antecedents           (whole milk, sausage)
# consequents                        (yogurt)
# antecedent support               0.00895542
# consequent support                0.0858785
# support                          0.00147029
# confidence                         0.164179
# lift                                1.91176
# leverage                        0.000701215
# conviction                          1.09368
# Name: 22, dtype: object)
# (25, antecedents                      (sausage)
# consequents           (whole milk, yogurt)
# antecedent support               0.0603489
# consequent support               0.0111609
# support                         0.00147029
# confidence                       0.0243632
# lift                               2.18292
# leverage                       0.000796748
# conviction                         1.01353
# Name: 25, dtype: object)

# %% [markdown]
# There is 'sausage' in results. It shows that sausage is usually bought with:
# * beverages
# * curd
# * whole milk and soda
# * yogurt

# %%
support = rules['support'].values
confidence = rules['confidence'].values
lift = rules['lift'].values

# %%
import random

# %%
for i in range(len(support)):
    support[i] = support[i] + 0.0025*(random.randint(1,10) -5)
    confidence[i] = confidence[i] + 0.0025*(random.randint(1,10) - 5)

# %%
plt.scatter(support, confidence, s=lift*100, alpha=0.8, c=lift)
plt.xlabel('support')
plt.ylabel('confidence')
plt.show()

# %%
result = df.apply(pd.value_counts).fillna(0)
result
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# False                  14903     14643             14941             14934
# True                      60       320                22                29
#
#        baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# False           14960  14959          14842             14946  14455    14637
# True                3      4            121                17    508      326
#
#        ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# False  ...   14883    14912    14686               14309   14955        14604
# True   ...      80       51      277                 654       8          359
#
#        white wine  whole milk  yogurt  zwieback
# False       14788       12600   13678     14903
# True          175        2363    1285        60
#
# [2 rows x 167 columns]

# %% [markdown]
# # 15 most purchased items

# %%
df_true = result.iloc[1,:]
df_true[:10]
# Out:
# Instant food products     60
# UHT-milk                 320
# abrasive cleaner          22
# artif. sweetener          29
# baby cosmetics             3
# bags                       4
# baking powder            121
# bathroom cleaner          17
# beef                     508
# berries                  326
# Name: True, dtype: int64

# %%
x = df_true.sort_values(ascending=False)

# %%
fifteen_products = x[:15]
fifteen_products
# Out:
# whole milk          2363
# other vegetables    1827
# rolls/buns          1646
# soda                1453
# yogurt              1285
# root vegetables     1041
# tropical fruit      1014
# bottled water        908
# sausage              903
# citrus fruit         795
# pastry               774
# pip fruit            734
# shopping bags        712
# canned beer          702
# bottled beer         678
# Name: True, dtype: int64

# %%
pos = np.arange(len(fifteen_products.values))

# %%
plt.figure(figsize=(10,6))
plt.bar(pos, fifteen_products.values, align='center')
plt.xticks(pos, fifteen_products.keys(), rotation='vertical')
plt.ylabel('Buying Times')
plt.xlabel('Names')
plt.title('Fifteen products best buy')
plt.show()

# %% [markdown]
# # 15 least purchased items

# %%
fifteen_products_least = x[-15:]
fifteen_products_least
# Out:
# specialty vegetables     11
# organic products         10
# liqueur                   9
# hair spray                9
# decalcifier               9
# whisky                    8
# salad dressing            6
# make up remover           5
# rubbing alcohol           5
# toilet cleaner            5
# frozen chicken            5
# bags                      4
# baby cosmetics            3
# kitchen utensil           1
# preservation products     1
# Name: True, dtype: int64

# %%
pos_l = np.arange(len(fifteen_products_least.values))

# %%
plt.figure(figsize=(10,6))
plt.bar(pos_l, fifteen_products_least.values, align='center')
plt.xticks(pos_l, fifteen_products_least.keys(), rotation='vertical')
plt.ylabel('Buying Times')
plt.xlabel('Names')
plt.title('Fifteen products best buy')
plt.show()
